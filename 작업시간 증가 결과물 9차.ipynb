# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

font_location = 'C:/Windows/Fonts/malgunsl.ttf'
font_name = fm.FontProperties(fname = font_location).get_name()
sns.set(rc = {'figure.figsize':(15, 8)})
matplotlib.rc('font' , family=font_name)#한글폰트 설정

# %%
df = pd.read_excel('data/자동차항만입출항전처리데이터.xlsx', index_col=0)

# %%
df
# Out:
#                      선명     호출부호  입항년도  입항월  입항횟수  입출    총톤수      계선 계선장소  \
# 0               TITANIA  9HA2272  2011   12     1   0  74255  MBJ 02  MBJ
# 1       WESTERN HIGHWAY    3EJK5  2011   12     1   0  39422  MBJ 02  MBJ
# 2      NORTHERN HIGHWAY    V7FT4  2012    1     1   1  39422  MBJ 01  MBJ
# 3      NORTHERN HIGHWAY    V7FT4  2012    1     1   0  39422  MBJ 03  MBJ
# 4              CAR STAR    A8VI6  2012    1     1   0  43790  MBJ 03  MBJ
# ...                 ...      ...   ...  ...   ...  ..    ...     ...  ...
# 11428      PRESTIGE ACE     H3NG  2021    8     2   1  55878  MBJ 01  MBJ
# 11429           PASSAMA    ZDNC6  2021    8     2   1  47053  MBJ 03  MBJ
# 11430         아세안 메저스티호    DSMZ8  2021    8     2   1  71383  MBJ 02  MBJ
# 11431      MORNING LILY    3FDI5  2021    8     2   1  70853  MBJ 03  MBJ
# 11432             모닝 세실    3FHK6  2021    8     3   1  60876  MBJ 01  MBJ
#
#        계선장소.1        작업시간  예선  도선      차항지    전출항지  선사번호
# 0           2  116.000000   1   1    korea   korea  EUKO
# 1           2  107.583333   1   1     asia  e_asia  EVOL
# 2           1   38.000000   1   1  america   korea  GLVS
# 3           3   38.000000   1   1  america   korea  GLVS
# 4           3    7.750000   1   1   e_asia  e_asia  ZIMU
# ...       ...         ...  ..  ..      ...     ...   ...
# 11428       1   15.750000   1   1    korea    asia  GLVS
# 11429       3   73.000000   1   1   e_asia   korea  L53K
# 11430       2   39.750000   1   1    korea   korea  EUKO
# 11431       3   15.750000   1   1    korea   korea  EUKO
# 11432       1   15.750000   1   1  america   korea  EUKO
#
# [11430 rows x 16 columns]

# %%
sns.histplot(x=df["입항년도"], y=df["작업시간"])
# Out:
# <AxesSubplot:xlabel='입항년도', ylabel='작업시간'>

# %%
a = df[["입항년도", "작업시간"]].groupby(["입항년도"]).mean()
a
# Out:
#             작업시간
# 입항년도
# 2011  111.791667
# 2012   23.912594
# 2013   26.222733
# 2014   23.806008
# 2015   24.873954
# 2016   34.523041
# 2017   30.909955
# 2018   33.756974
# 2019   33.143186
# 2020   37.611747
# 2021   34.982181

# %%
a.drop(2011, inplace=True)
a
# Out:
#            작업시간
# 입항년도
# 2012  23.912594
# 2013  26.222733
# 2014  23.806008
# 2015  24.873954
# 2016  34.523041
# 2017  30.909955
# 2018  33.756974
# 2019  33.143186
# 2020  37.611747
# 2021  34.982181

# %%
a.reset_index()
# Out:
#    입항년도       작업시간
# 0  2012  23.912594
# 1  2013  26.222733
# 2  2014  23.806008
# 3  2015  24.873954
# 4  2016  34.523041
# 5  2017  30.909955
# 6  2018  33.756974
# 7  2019  33.143186
# 8  2020  37.611747
# 9  2021  34.982181

# %%
sns.lineplot(x="입항년도", y="작업시간", data=a)
# Out:
# <AxesSubplot:xlabel='입항년도', ylabel='작업시간'>
